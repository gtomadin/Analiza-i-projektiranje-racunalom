# %%
# 1. EULER

import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %pylab inline

X_1 = np.array([
[0.9900000000000007 , 1.388709198864032 ,-0.30263193019932916],
[1.9900000000000015 , 0.4981958315789182 ,-1.3387313222544912], 
[2.9899999999999802 , -0.861586089036513 ,-1.148292379113695], 
[3.989999999999959 , -1.4389515976426452 ,0.10505086894000314], 
[4.989999999999938 , -0.6925678828131816 ,1.273925690316826], 
[5.989999999999917 , 0.7012303404363228 ,1.277475139545681], 
[6.989999999999895 , 1.4611182888577345 ,0.10070849730888863], 
[7.989999999999874 , 0.8786098919516702 ,-1.1809361233416014], 
[8.989999999999853 , -0.521563802265817 ,-1.3843084629830518], 
[9.989999999999831 , -1.4538982142764794 ,-0.3106618221316094] 
])
    
#plt.scatter(X[1], X[0])

print(X_1)
t_1 = []
X1_1 = []
X2_1 = []
for i in range(10):
    t_1.append(X_1[i][0])
    X1_1.append(X_1[i][1])
    X2_1.append(X_1[i][2])    
    
plt.plot(t_1, X1_1, t_1, X2_1)
print()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [[ 0.99        1.3887092  -0.30263193]
#  [ 1.99        0.49819583 -1.33873132]
#  [ 2.99       -0.86158609 -1.14829238]
#  [ 3.99       -1.4389516   0.10505087]
#  [ 4.99       -0.69256788  1.27392569]
#  [ 5.99        0.70123034  1.27747514]
#  [ 6.99        1.46111829  0.1007085 ]
#  [ 7.99        0.87860989 -1.18093612]
#  [ 8.99       -0.5215638  -1.38430846]
#  [ 9.99       -1.45389821 -0.31066182]]

# %%
#ReverseEuler

X_2 = np.array([
[0.9900000000000007 , 1.374891998861273 ,-0.29962084198143213 ],
[1.9900000000000015 , 0.48833138145919386, -1.3122239781238918 ],
[2.9899999999999802 , -0.8361236259738973, -1.1143568819413108 ],
[3.989999999999959 , -1.3825322633438444, 0.10093196730160509 ],
[4.989999999999938 , -0.6587925954656938, 1.2117986305475765 ],
[5.989999999999917 , 0.6603958455486271, 1.2030843879668505 ],
[6.989999999999895 , 1.3623424305547953, 0.09390030913141868 ],
[7.989999999999874 , 0.8110623973844059, -1.0901457997788766 ],
[8.989999999999853 , -0.47667556889160145, -1.2651683672203937 ],
[9.989999999999831 , -1.3155480835784896, -0.2810998464219318 ]
])

print(X_2)
t_2 = []
X1_2 = []
X2_2 = []
for i in range(10):
    t_2.append(X_2[i][0])
    X1_2.append(X_2[i][1])
    X2_2.append(X_2[i][2])    
    
plt.plot(t_2, X1_2, t_2, X2_2)
print()
# Out:
# [[ 0.99        1.374892   -0.29962084]
#  [ 1.99        0.48833138 -1.31222398]
#  [ 2.99       -0.83612363 -1.11435688]
#  [ 3.99       -1.38253226  0.10093197]
#  [ 4.99       -0.6587926   1.21179863]
#  [ 5.99        0.66039585  1.20308439]
#  [ 6.99        1.36234243  0.09390031]
#  [ 7.99        0.8110624  -1.0901458 ]
#  [ 8.99       -0.47667557 -1.26516837]
#  [ 9.99       -1.31554808 -0.28109985]]

# %%
#Trapezoid

X_3 = np.array([
[0.9900000000000007 , 1.381775800329404 ,-0.30115716432459233 ],
[1.9900000000000015 , 0.4931726806164124, -1.3254360441355217 ],
[2.9899999999999802 , -0.8488442108868658, -1.1311337258007466 ],
[3.989999999999959 , -1.41044955396556, 0.10311186022168511 ],
[4.989999999999938 , -0.675313862272988, 1.2425583235494282 ],
[5.989999999999917 , 0.6806928092409903, 1.2396198205287252 ],
[6.989999999999895 , 1.4108831973332754, 0.09699795607484372 ],
[7.989999999999874 , 0.8439338670233967 ,-1.1348020215398795 ],
[8.989999999999853 , -0.4989125330721933 ,-1.3232861687267699 ],
[9.989999999999831 , -1.3830680479975792 ,-0.2951656731536711 ]
])

print(X_3)
t_3 = []
X1_3 = []
X2_3 = []
for i in range(10):
    t_3.append(X_3[i][0])
    X1_3.append(X_3[i][1])
    X2_3.append(X_3[i][2])    
    
plt.plot(t_3, X1_3, t_3, X2_3)
print()
# Out:
# [[ 0.99        1.3817758  -0.30115716]
#  [ 1.99        0.49317268 -1.32543604]
#  [ 2.99       -0.84884421 -1.13113373]
#  [ 3.99       -1.41044955  0.10311186]
#  [ 4.99       -0.67531386  1.24255832]
#  [ 5.99        0.68069281  1.23961982]
#  [ 6.99        1.4108832   0.09699796]
#  [ 7.99        0.84393387 -1.13480202]
#  [ 8.99       -0.49891253 -1.32328617]
#  [ 9.99       -1.38306805 -0.29516567]]

# %%
#RungeKutta

X_4 = np.array([
[0.9900000000000007 , 1.3829264705979902, -0.30141398804812997 ],
[1.9900000000000015 , 0.49398423276450315, -1.3276509981250328 ],
[2.9899999999999802 , -0.8509830885931354, -1.1339543780602608 ],
[3.989999999999959 , -1.4151570349890532, 0.1034797156134092 ],
[4.989999999999938 , -0.6781074632260256, 1.247760426748179 ],
[5.989999999999917 , 0.6841358417401698, 1.2458161561906897 ],
[6.989999999999895 , 1.4191400042543614, 0.09752402321481557 ],
[7.989999999999874 , 0.8495406435388057, -1.1424207385967715 ],
[8.989999999999853 , -0.5027183301971325, -1.3332289831464559 ],
[9.989999999999831 , -1.394653833134012, -0.29757748225804975 ]
])

print(X_4)
t_4 = []
X1_4 = []
X2_4 = []
for i in range(10):
    t_4.append(X_4[i][0])
    X1_4.append(X_4[i][1])
    X2_4.append(X_4[i][2])    
    
plt.plot(t_4, X1_4, t_4, X2_4)
print()
# Out:
# [[ 0.99        1.38292647 -0.30141399]
#  [ 1.99        0.49398423 -1.327651  ]
#  [ 2.99       -0.85098309 -1.13395438]
#  [ 3.99       -1.41515703  0.10347972]
#  [ 4.99       -0.67810746  1.24776043]
#  [ 5.99        0.68413584  1.24581616]
#  [ 6.99        1.41914     0.09752402]
#  [ 7.99        0.84954064 -1.14242074]
#  [ 8.99       -0.50271833 -1.33322898]
#  [ 9.99       -1.39465383 -0.29757748]]

# %%
#PredictorCorrectorEulerReverseEuler
X_5 = np.array([
[0.9900000000000007 , 1.3748906239699583, -0.2996205423607391 ],
[1.9900000000000015 , 0.48833040479740536, -1.3122213536785525 ],
[2.9899999999999802 , -0.8361211176067749, -1.1143535388756707 ],
[3.989999999999959 , -1.3825267332258333 ,0.1009315635745408 ],
[4.989999999999938 , -0.6587893015109422 ,1.2117925715695508 ],
[5.989999999999917 , 0.6603918831854252 ,1.2030771694821534 ],
[6.989999999999895 , 1.3623328941911264 ,0.09389965183155548 ],
[7.989999999999874 , 0.8110559089111604 ,-1.0901370786473323 ],
[8.989999999999853 , -0.47667127883077 ,-1.2651569807562908 ],
[9.989999999999831 , -1.3155349281633861 ,-0.28109703543751624 ],
])

print(X_5)
t_5 = []
X1_5 = []
X2_5 = []
for i in range(10):
    t_5.append(X_5[i][0])
    X1_5.append(X_5[i][1])
    X2_5.append(X_5[i][2])    
    
plt.plot(t_5, X1_5, t_5, X2_5)
print()
# Out:
# [[ 0.99        1.37489062 -0.29962054]
#  [ 1.99        0.4883304  -1.31222135]
#  [ 2.99       -0.83612112 -1.11435354]
#  [ 3.99       -1.38252673  0.10093156]
#  [ 4.99       -0.6587893   1.21179257]
#  [ 5.99        0.66039188  1.20307717]
#  [ 6.99        1.36233289  0.09389965]
#  [ 7.99        0.81105591 -1.09013708]
#  [ 8.99       -0.47667128 -1.26515698]
#  [ 9.99       -1.31553493 -0.28109704]]

# %%
#PredictorCorrectorEulerTrapezoid

X_6 = np.array([
[0.9900000000000007 , 1.3817684438777877, -0.3011917454108289 ],
[1.9900000000000015 , 0.49310653313125447, -1.3254610318615654 ],
[2.9899999999999802 , -0.848929359756482, -1.131070485046803 ],
[3.989999999999959 , -1.410439941205231, 0.1032529527615687 ],
[4.989999999999938 , -0.6751589630646305, 1.2426435026165195 ],
[5.989999999999917 , 0.6808792505665054, 1.2395186348539655 ],
[6.989999999999895 , 1.4109013844862035, 0.09675114086133671 ],
[7.989999999999874 , 0.8437077391242227, -1.1349719163688077 ],
[8.989999999999853 , -0.4992108139977177, -1.323175371291647 ],
[9.989999999999831 , -1.3831435232798397, -0.2948202740912988 ]
])

print(X_6)
t_6 = []
X1_6 = []
X2_6 = []
for i in range(10):
    t_6.append(X_6[i][0])
    X1_6.append(X_6[i][1])
    X2_6.append(X_6[i][2])    
    
plt.plot(t_6, X1_6, t_6, X2_6)
print()
# Out:
# [[ 0.99        1.38176844 -0.30119175]
#  [ 1.99        0.49310653 -1.32546103]
#  [ 2.99       -0.84892936 -1.13107049]
#  [ 3.99       -1.41043994  0.10325295]
#  [ 4.99       -0.67515896  1.2426435 ]
#  [ 5.99        0.68087925  1.23951863]
#  [ 6.99        1.41090138  0.09675114]
#  [ 7.99        0.84370774 -1.13497192]
#  [ 8.99       -0.49921081 -1.32317537]
#  [ 9.99       -1.38314352 -0.29482027]]
