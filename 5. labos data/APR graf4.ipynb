# %%
# 1. EULER

import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %pylab inline

X_1 = np.array([
[0.09 , -2.2197478531377746, 1.3388733613233255 ],
[0.19000000000000003 , -2.8563764799921723, 0.49122801381724784 ],
[0.2900000000000001 , -3.1740027165221774, 0.06929655206399457 ],
[0.3900000000000002 , -3.3096712728525253, -0.12878168303046214 ],
[0.49000000000000027 , -3.3342388275634334, -0.2080551379233182 ],
[0.5900000000000003 , -3.284078620225286, -0.22315552930134852 ],
[0.6900000000000004 , -3.177589941606597, -0.20245799819443377 ],
[0.7900000000000005 , -3.0237948301574606, -0.16066232067047237 ],
[0.8900000000000006 , -2.826814201606677, -0.10534443673999445 ],
[0.9900000000000007 , -2.588198195104832, -0.04036804884961928 ]
])
    
#plt.scatter(X[1], X[0])

print(X_1)
t_1 = []
X1_1 = []
X2_1 = []
for i in range(10):
    t_1.append(X_1[i][0])
    X1_1.append(X_1[i][1])
    X2_1.append(X_1[i][2])    
    
plt.plot(t_1, X1_1, t_1, X2_1)
print()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [[ 0.09       -2.21974785  1.33887336]
#  [ 0.19       -2.85637648  0.49122801]
#  [ 0.29       -3.17400272  0.06929655]
#  [ 0.39       -3.30967127 -0.12878168]
#  [ 0.49       -3.33423883 -0.20805514]
#  [ 0.59       -3.28407862 -0.22315553]
#  [ 0.69       -3.17758994 -0.202458  ]
#  [ 0.79       -3.02379483 -0.16066232]
#  [ 0.89       -2.8268142  -0.10534444]
#  [ 0.99       -2.5881982  -0.04036805]]

# %%
#ReverseEuler

X_2 = np.array([
[0.09 , -2.165586729240304, 1.4141350267685109 ],
[0.19000000000000003 , -2.7958025831920312, 0.571623045538909 ],
[0.2900000000000001 , -3.12104836138772, 0.13402176988672648 ],
[0.3900000000000002 , -3.265721029212404, -0.08203462914237504 ],
[0.49000000000000027 , -3.296749569633122, -0.17586058657752204 ],
[0.5900000000000003 , -3.2499002475782643, -0.2012136769527278 ],
[0.6900000000000004 , -3.144033187788756, -0.18715804860711527 ],
[0.7900000000000005 , -2.9888287149076, -0.14937204410153657 ],
[0.8900000000000006 , -2.788974378107519, -0.09627669948309062 ],
[0.9900000000000007 , -2.546433698187016, -0.03235722918938964 ]
])

print(X_2)
t_2 = []
X1_2 = []
X2_2 = []
for i in range(10):
    t_2.append(X_2[i][0])
    X1_2.append(X_2[i][1])
    X2_2.append(X_2[i][2])    
    
plt.plot(t_2, X1_2, t_2, X2_2)
print()
# Out:
# [[ 0.09       -2.16558673  1.41413503]
#  [ 0.19       -2.79580258  0.57162305]
#  [ 0.29       -3.12104836  0.13402177]
#  [ 0.39       -3.26572103 -0.08203463]
#  [ 0.49       -3.29674957 -0.17586059]
#  [ 0.59       -3.24990025 -0.20121368]
#  [ 0.69       -3.14403319 -0.18715805]
#  [ 0.79       -2.98882871 -0.14937204]
#  [ 0.89       -2.78897438 -0.0962767 ]
#  [ 0.99       -2.5464337  -0.03235723]]

# %%
#Trapezoid

X_3 = np.array([
[0.09 , -2.1685286988323322, 1.390016104097403 ],
[0.19000000000000003 , -2.7354129474530815, 0.5759350952347887 ],
[0.2900000000000001 , -2.9505826882475805, 0.18931001218444585 ],
[0.3900000000000002 , -2.9458738751770652, 0.03441633109640686 ],
[0.49000000000000027 , -2.7903112485779777, 0.0073524884119675355 ],
[0.5900000000000003 , -2.519495341786308, 0.05303423716532113 ],
[0.6900000000000004 , -2.1512233827340834, 0.14233319494611027 ],
[0.7900000000000005 , -1.6937921623847396, 0.25992395602426815 ],
[0.8900000000000006 , -1.1504106341277929, 0.3978238317480007 ],
[0.9900000000000007 , -0.5215444265540446, 0.5519587709987354 ],
])

print(X_3)
t_3 = []
X1_3 = []
X2_3 = []
for i in range(10):
    t_3.append(X_3[i][0])
    X1_3.append(X_3[i][1])
    X2_3.append(X_3[i][2])    
    
plt.plot(t_3, X1_3, t_3, X2_3)
print()
# Out:
# [[ 0.09       -2.1685287   1.3900161 ]
#  [ 0.19       -2.73541295  0.5759351 ]
#  [ 0.29       -2.95058269  0.18931001]
#  [ 0.39       -2.94587388  0.03441633]
#  [ 0.49       -2.79031125  0.00735249]
#  [ 0.59       -2.51949534  0.05303424]
#  [ 0.69       -2.15122338  0.14233319]
#  [ 0.79       -1.69379216  0.25992396]
#  [ 0.89       -1.15041063  0.39782383]
#  [ 0.99       -0.52154443  0.55195877]]

# %%
#RungeKutta

X_4 = np.array([
[0.09 , -2.1964881193203167, 1.3712496218259005 ],
[0.19000000000000003 , -2.830670544785776, 0.5254168534979675 ],
[0.2900000000000001 , -3.151782683401543, 0.09650551120149356 ],
[0.3900000000000002 , -3.2914044361351618, -0.10935363778810339 ],
[0.49000000000000027 , -3.3187562566316413, -0.19482030572611234 ],
[0.5900000000000003 , -3.2699991666882684, -0.21422149883807307 ],
[0.6900000000000004 , -3.1637598581164146, -0.19627120095079062 ],
[0.7900000000000005 , -3.00935666625537, -0.15610910593379226 ],
[0.8900000000000006 , -2.811157832109171, -0.10167967850948773 ],
[0.9900000000000007 , -2.5708903068317923, -0.037112240998656794 ],
])

print(X_4)
t_4 = []
X1_4 = []
X2_4 = []
for i in range(10):
    t_4.append(X_4[i][0])
    X1_4.append(X_4[i][1])
    X2_4.append(X_4[i][2])    
    
plt.plot(t_4, X1_4, t_4, X2_4)
print()
# Out:
# [[ 0.09       -2.19648812  1.37124962]
#  [ 0.19       -2.83067054  0.52541685]
#  [ 0.29       -3.15178268  0.09650551]
#  [ 0.39       -3.29140444 -0.10935364]
#  [ 0.49       -3.31875626 -0.19482031]
#  [ 0.59       -3.26999917 -0.2142215 ]
#  [ 0.69       -3.16375986 -0.1962712 ]
#  [ 0.79       -3.00935667 -0.15610911]
#  [ 0.89       -2.81115783 -0.10167968]
#  [ 0.99       -2.57089031 -0.03711224]]

# %%
#PredictorCorrectorEulerReverseEuler
X_5 = np.array([
[0.09 , -2.170366699189233, 1.4115331314335264 ],
[0.19000000000000003 , -2.8047011920240528, 0.5675285369690661 ],
[0.2900000000000001 , -3.1338031307232246, 0.12896483967680705 ],
[0.3900000000000002 , -3.282267342096706, -0.08780861742634795 ],
[0.49000000000000027 , -3.3171209507446875, -0.18224502325577568 ],
[0.5900000000000003 , -3.2741793365462026, -0.2081688076938365 ],
[0.6900000000000004 , -3.17232791526475, -0.19467595066480023 ],
[0.7900000000000005 , -3.0212609077575827, -0.15745978518518797 ],
[0.8900000000000006 , -2.8256744351615124, -0.10494837445234606 ],
[0.9900000000000007 , -2.5875381962654904, -0.04163027914707178 ]
])

print(X_5)
t_5 = []
X1_5 = []
X2_5 = []
for i in range(10):
    t_5.append(X_5[i][0])
    X1_5.append(X_5[i][1])
    X2_5.append(X_5[i][2])    
    
plt.plot(t_5, X1_5, t_5, X2_5)
print()
# Out:
# [[ 0.09       -2.1703667   1.41153313]
#  [ 0.19       -2.80470119  0.56752854]
#  [ 0.29       -3.13380313  0.12896484]
#  [ 0.39       -3.28226734 -0.08780862]
#  [ 0.49       -3.31712095 -0.18224502]
#  [ 0.59       -3.27417934 -0.20816881]
#  [ 0.69       -3.17232792 -0.19467595]
#  [ 0.79       -3.02126091 -0.15745979]
#  [ 0.89       -2.82567444 -0.10494837]
#  [ 0.99       -2.5875382  -0.04163028]]

# %%
#PredictorCorrectorEulerTrapezoid

X_6 = np.array([
[0.09 , -2.193604176054917, 1.3773289694229507 ],
[0.19000000000000003 , -2.829274229973184, 0.5312277088372861 ],
[0.2900000000000001 , -3.15312295394283, 0.10027067552636312 ],
[0.3900000000000002 , -3.2955843211328166, -0.10773322864899401 ],
[0.49000000000000027 , -3.325542399650926, -0.19495017524080163 ],
[0.5900000000000003 , -3.27912426011426, -0.21565615941578387 ],
[0.6900000000000004 , -3.1750155974655874, -0.19865014561572242 ],
[0.7900000000000005 , -3.022607210480679, -0.15917647383628558 ],
[0.8900000000000006 , -2.8263279008254667, -0.10526680540404808 ],
[0.9900000000000007 , -2.5879487532448313, -0.04111358859387966 ]
])

print(X_6)
t_6 = []
X1_6 = []
X2_6 = []
for i in range(10):
    t_6.append(X_6[i][0])
    X1_6.append(X_6[i][1])
    X2_6.append(X_6[i][2])    
    
plt.plot(t_6, X1_6, t_6, X2_6)
print()
# Out:
# [[ 0.09       -2.19360418  1.37732897]
#  [ 0.19       -2.82927423  0.53122771]
#  [ 0.29       -3.15312295  0.10027068]
#  [ 0.39       -3.29558432 -0.10773323]
#  [ 0.49       -3.3255424  -0.19495018]
#  [ 0.59       -3.27912426 -0.21565616]
#  [ 0.69       -3.1750156  -0.19865015]
#  [ 0.79       -3.02260721 -0.15917647]
#  [ 0.89       -2.8263279  -0.10526681]
#  [ 0.99       -2.58794875 -0.04111359]]
