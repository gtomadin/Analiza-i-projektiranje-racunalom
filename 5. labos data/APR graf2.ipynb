# %%
# EULER

import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %pylab inline

X_1 = np.array([
[0.0 , 0.8 ,-1.6 ],
[0.1 , 0.64, -1.2799999999999985 ],
[0.2 , 0.5120000000000001, -1.0240000000000153 ],
[0.30000000000000004 , 0.4095999999999986, -0.8191999999998603 ],
[0.4 , 0.3276800000000125, -0.6553600000012567 ],
[0.5 , 0.26214399999988686, -0.5242879999886882 ],
[0.6 , 0.20971520000101804, -0.41943040010180554 ],
[0.7 , 0.16777215999083747, -0.33554431908374993 ],
[0.7999999999999999 , 0.13421772808246246, -0.2684354642462503 ],
[0.8999999999999999 , 0.10737418165783744, -0.21474829058374617 ],
[0.9999999999999999 , 0.08589935259946282, -0.17179935978628413 ]
])
    
#plt.scatter(X[1], X[0])

print(X_1)
t_1 = []
X1_1 = []
X2_1 = []
for i in range(10):
    t_1.append(X_1[i][0])
    X1_1.append(X_1[i][1])
    X2_1.append(X_1[i][2])    
    
plt.plot(t_1, X1_1, t_1, X2_1)
print()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [[ 0.          0.8        -1.6       ]
#  [ 0.1         0.64       -1.28      ]
#  [ 0.2         0.512      -1.024     ]
#  [ 0.3         0.4096     -0.8192    ]
#  [ 0.4         0.32768    -0.65536   ]
#  [ 0.5         0.262144   -0.524288  ]
#  [ 0.6         0.2097152  -0.4194304 ]
#  [ 0.7         0.16777216 -0.33554432]
#  [ 0.8         0.13421773 -0.26843546]
#  [ 0.9         0.10737418 -0.21474829]
#  [ 1.          0.08589935 -0.17179936]]

# %%
#ReverseEuler

X_2 = np.array([
[0.0 , 0.8333333333333335, -1.6666666666666667 ],
[0.1 , 0.6944444444444446, -1.388888888888889 ],
[0.2 , 0.578703703703704, -1.1574074074074079 ],
[0.30000000000000004 , 0.48225308641975345, -0.9645061728395068 ],
[0.4 , 0.4018775720164613, -0.8037551440329225 ],
[0.5 , 0.33489797668038446, -0.6697959533607688 ],
[0.6 , 0.2790816472336538, -0.5581632944673074 ],
[0.7 , 0.23256803936137824, -0.46513607872275636 ],
[0.7999999999999999 , 0.19380669946781523, -0.3876133989356304 ],
[0.8999999999999999 , 0.16150558288984604, -0.323011165779692 ],
[0.9999999999999999 , 0.1345879857415384, -0.26917597148307676 ]
])

print(X_2)
t_2 = []
X1_2 = []
X2_2 = []
for i in range(10):
    t_2.append(X_2[i][0])
    X1_2.append(X_2[i][1])
    X2_2.append(X_2[i][2])    
    
plt.plot(t_2, X1_2, t_2, X2_2)
print()
# Out:
# [[ 0.          0.83333333 -1.66666667]
#  [ 0.1         0.69444444 -1.38888889]
#  [ 0.2         0.5787037  -1.15740741]
#  [ 0.3         0.48225309 -0.96450617]
#  [ 0.4         0.40187757 -0.80375514]
#  [ 0.5         0.33489798 -0.66979595]
#  [ 0.6         0.27908165 -0.55816329]
#  [ 0.7         0.23256804 -0.46513608]
#  [ 0.8         0.1938067  -0.3876134 ]
#  [ 0.9         0.16150558 -0.32301117]
#  [ 1.          0.13458799 -0.26917597]]

# %%
#Trapezoid

X_3 = np.array([
[0.0 , 0.8181818181818181, -1.636363636363636 ],
[0.1 , 0.6694214876033058, -1.3388429752066113 ],
[0.2 , 0.5477084898572502, -1.0954169797145004 ],
[0.30000000000000004 , 0.4481251280650228, -0.8962502561300454 ],
[0.4 , 0.36664783205320045, -0.7332956641064009 ],
[0.5 , 0.2999845898617095, -0.5999691797234188 ],
[0.6 , 0.24544193715958051, -0.4908838743191611 ],
[0.7 , 0.20081613040329313, -0.4016322608065862 ],
[0.7999999999999999 , 0.16430410669360346, -0.32860821338720686 ],
[0.8999999999999999 , 0.1344306327493119, -0.2688612654986238 ],
[0.9999999999999999 , 0.10998869952216428, -0.2199773990443285 ]
])

print(X_3)
t_3 = []
X1_3 = []
X2_3 = []
for i in range(10):
    t_3.append(X_3[i][0])
    X1_3.append(X_3[i][1])
    X2_3.append(X_3[i][2])    
    
plt.plot(t_3, X1_3, t_3, X2_3)
print()
# Out:
# [[ 0.          0.81818182 -1.63636364]
#  [ 0.1         0.66942149 -1.33884298]
#  [ 0.2         0.54770849 -1.09541698]
#  [ 0.3         0.44812513 -0.89625026]
#  [ 0.4         0.36664783 -0.73329566]
#  [ 0.5         0.29998459 -0.59996918]
#  [ 0.6         0.24544194 -0.49088387]
#  [ 0.7         0.20081613 -0.40163226]
#  [ 0.8         0.16430411 -0.32860821]
#  [ 0.9         0.13443063 -0.26886127]
#  [ 1.          0.1099887  -0.2199774 ]]

# %%
#RungeKutta

X_4 = np.array([
[0.0 , 0.8157000000000001, -1.6314000000000026 ],
[0.1 , 0.665366490000003, -1.330732980000296 ],
[0.2 , 0.542739445893343, -1.0854788918203004 ],
[0.30000000000000004 , 0.44271256605470877, -0.8854251360087044 ],
[0.4 , 0.3611206447138528, -0.7222417417449885 ],
[0.5 , 0.29456664152420803, -0.5891857518532162 ],
[0.6 , 0.2403396787010183, -0.48676573875884954 ],
[0.7 , 0.2031987042441507, -1.1124176458786028 ],
[0.7999999999999999 , 0.9955700690686444, -83.88948767541227 ],
[0.8999999999999999 , 97.07130928327545, -9694.35093289045 ],
[0.9999999999999999 , 11245.250909222965, -1124514.6662800184 ]
])

print(X_4)
t_4 = []
X1_4 = []
X2_4 = []
for i in range(10):
    t_4.append(X_4[i][0])
    X1_4.append(X_4[i][1])
    X2_4.append(X_4[i][2])    
    
plt.plot(t_4, X1_4, t_4, X2_4)
print()
# Out:
# [[ 0.00000000e+00  8.15700000e-01 -1.63140000e+00]
#  [ 1.00000000e-01  6.65366490e-01 -1.33073298e+00]
#  [ 2.00000000e-01  5.42739446e-01 -1.08547889e+00]
#  [ 3.00000000e-01  4.42712566e-01 -8.85425136e-01]
#  [ 4.00000000e-01  3.61120645e-01 -7.22241742e-01]
#  [ 5.00000000e-01  2.94566642e-01 -5.89185752e-01]
#  [ 6.00000000e-01  2.40339679e-01 -4.86765739e-01]
#  [ 7.00000000e-01  2.03198704e-01 -1.11241765e+00]
#  [ 8.00000000e-01  9.95570069e-01 -8.38894877e+01]
#  [ 9.00000000e-01  9.70713093e+01 -9.69435093e+03]
#  [ 1.00000000e+00  1.12452509e+04 -1.12451467e+06]]

# %%
#PredictorCorrectorEulerReverseEuler
X_5 = np.array([
[0.0 , 0.8320000000000002 ,-1.6640000000000157 ],
[0.1 , 0.6922239999998578 ,-1.384447999985781 ],
[0.2 , 0.5759303681292504 ,-1.1518607489250356 ],
[0.30000000000000004 , 0.47917394868742635, -0.9583363834946339 ],
[0.4 , 0.39877962017188906, -0.8080253574625729 ],
[0.5 , 0.23461721265212168, 9.044466035680141 ],
[0.6 , 88.5203966007056, -8824.994512236217 ],
[0.7 , -80213.95335754738, 8021417.837317736 ],
[0.7999999999999999 , 7.291469250652145E7, -7.291469231930844E9 ],
[0.8999999999999999 , -6.627945531461945E10, 6.627945531477522E12 ],
[0.9999999999999999 , 6.024802488113371E13, -6.024802488113357E15 ]
])

print(X_5)
t_5 = []
X1_5 = []
X2_5 = []
for i in range(10):
    t_5.append(X_5[i][0])
    X1_5.append(X_5[i][1])
    X2_5.append(X_5[i][2])    
    
plt.plot(t_5, X1_5, t_5, X2_5)
print()
# Out:
# [[ 0.00000000e+00  8.32000000e-01 -1.66400000e+00]
#  [ 1.00000000e-01  6.92224000e-01 -1.38444800e+00]
#  [ 2.00000000e-01  5.75930368e-01 -1.15186075e+00]
#  [ 3.00000000e-01  4.79173949e-01 -9.58336383e-01]
#  [ 4.00000000e-01  3.98779620e-01 -8.08025357e-01]
#  [ 5.00000000e-01  2.34617213e-01  9.04446604e+00]
#  [ 6.00000000e-01  8.85203966e+01 -8.82499451e+03]
#  [ 7.00000000e-01 -8.02139534e+04  8.02141784e+06]
#  [ 8.00000000e-01  7.29146925e+07 -7.29146923e+09]
#  [ 9.00000000e-01 -6.62794553e+10  6.62794553e+12]
#  [ 1.00000000e+00  6.02480249e+13 -6.02480249e+15]]

# %%
#PredictorCorrectorEulerTrapezoid

X_6 = np.array([
[0.0 , 0.82 ,-1.6399999999999992 ],
[0.1 , 0.6723999999999996, -1.3447999999999654 ],
[0.2 , 0.5513679999999859 ,-1.1027359999985968 ],
[0.30000000000000004 , 0.45212175999942467, -0.9042435199424752 ],
[0.4 , 0.37073984317641484, -0.7414796840414895 ],
[0.5 , 0.3040066704570107, -0.6080132461490753 ],
[0.6 , 0.24928543092112085, -0.4985669764794498 ],
[0.7 , 0.2044124603565744, -0.4086656208386803 ],
[0.7999999999999999 , 0.16755290454385893, -0.32857451423451034 ],
[0.8999999999999999 , 0.13471555083614922, -0.0016480126907893466 ],
[0.9999999999999999 , 6.756852032236416E-4, 10.977755277835424 ]
])

print(X_6)
t_6 = []
X1_6 = []
X2_6 = []
for i in range(10):
    t_6.append(X_6[i][0])
    X1_6.append(X_6[i][1])
    X2_6.append(X_6[i][2])    
    
plt.plot(t_6, X1_6, t_6, X2_6)
print()
# Out:
# [[ 0.00000000e+00  8.20000000e-01 -1.64000000e+00]
#  [ 1.00000000e-01  6.72400000e-01 -1.34480000e+00]
#  [ 2.00000000e-01  5.51368000e-01 -1.10273600e+00]
#  [ 3.00000000e-01  4.52121760e-01 -9.04243520e-01]
#  [ 4.00000000e-01  3.70739843e-01 -7.41479684e-01]
#  [ 5.00000000e-01  3.04006670e-01 -6.08013246e-01]
#  [ 6.00000000e-01  2.49285431e-01 -4.98566976e-01]
#  [ 7.00000000e-01  2.04412460e-01 -4.08665621e-01]
#  [ 8.00000000e-01  1.67552905e-01 -3.28574514e-01]
#  [ 9.00000000e-01  1.34715551e-01 -1.64801269e-03]
#  [ 1.00000000e+00  6.75685203e-04  1.09777553e+01]]
